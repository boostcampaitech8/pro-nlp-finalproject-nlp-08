# %%
import pickle

cache = pickle.load(open("embeddings.pkl", "rb"))
for i, key in enumerate(cache.keys()):
    print(i, key)
# Out:
# 0 /data/ephemeral/home/REPO_2eeg/test/test_dir/20240217_150712_puduck.jpg
# 1 /data/ephemeral/home/REPO_2eeg/test/test_dir/20230617_122951.jpg
# 2 /data/ephemeral/home/REPO_2eeg/test/test_dir/20240217_150603_puduck.jpg
# 3 /data/ephemeral/home/REPO_2eeg/test/test_dir/20230511_141036.jpg
# 4 /data/ephemeral/home/REPO_2eeg/test/test_dir/20251225_130745_mww.jpg
# 5 /data/ephemeral/home/REPO_2eeg/test/test_dir/20230322_084848.jpg
# 6 /data/ephemeral/home/REPO_2eeg/test/test_dir/20240929_075105.jpg
# 7 /data/ephemeral/home/REPO_2eeg/test/test_dir/20230330_145318.jpg
# 8 /data/ephemeral/home/REPO_2eeg/test/test_dir/20230424_120119_puduck.jpg
# 9 /data/ephemeral/home/REPO_2eeg/test/test_dir/file1.txt
# 10 /data/ephemeral/home/REPO_2eeg/test/test_dir/20230322_082239.jpg
# 11 /data/ephemeral/home/REPO_2eeg/test/test_dir/20230423_114719_puduck.jpg
# 12 /data/ephemeral/home/REPO_2eeg/test/test_dir/20220228_152415.jpg
# 13 /data/ephemeral/home/REPO_2eeg/test/test_dir/20240111_143541.jpg
# ...
